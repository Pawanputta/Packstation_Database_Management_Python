# %%
# !pip install "pymongo[srv]"

# %%
import pymongo
import pandas as pd

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://packstation:pack@cluster0.f6o7lcv.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db = client["PackstationDatabase"]
collection = db["PackstationCollection"]
df1= pd.read_csv('compartments.csv')
df1
# Out:
#     compartment_id compartment_size     status is_express lock_code
# 0                1            small  available         no  lock_123
# 1                2           medium   occupied         no  lock_456
# 2                3            large  available         no  lock_789
# 3                4            small   occupied         no  lock_101
# 4                5           medium  available         no  lock_102
# 5                6            large   occupied         no  lock_103
# 6                7            small  available         no  lock_104
# 7                8           medium  available         no  lock_105
# 8                9            large   occupied         no  lock_106
# 9               10            small  available         no  lock_107
# 10              11           medium  available        yes  lock_108
# 11              12            large  available         no  lock_109
# 12              13            small   occupied         no  lock_110
# ...

# %%
db = client["PackstationDatabase"]
collection = db["PackstationCollection"]
df2= pd.read_csv('customers.csv')
df2
# Out:
#    customer_id           name                      email  phone_number
# 0            1       John Doe       john.doe@example.com  123-456-7890
# 1            2     Jane Smith     jane.smith@example.com  234-567-8901
# 2            3    Bob Johnson    bob.johnson@example.com  345-678-9012
# 3            4    Alice Brown    alice.brown@example.com  456-789-0123
# 4            5  Charlie Davis  charlie.davis@example.com  567-890-1234

# %%
db = client["PackstationDatabase"]
collection = db["PackstationCollection"]
df3= pd.read_csv('notifications.csv')
df3
# Out:
#    notification_id  customer_id  compartment_id pickup_code notification_type  \
# 0                1            1               2  pickup_abc             email
# 1                2            2               4  pickup_def               sms
# 2                3            3               6  pickup_ghi             email
# 3                4            4               8  pickup_jkl               sms
# 4                5            5              10  pickup_mno             email
#
#                                         instructions
# 0  Retrieve your parcel using the pickup code at ...
# 1  Retrieve your parcel using the pickup code at ...
# 2  Retrieve your parcel using the pickup code at ...
# 3  Retrieve your parcel using the pickup code at ...
# 4  Retrieve your parcel using the pickup code at ...

# %%
data1 = df1.to_dict(orient='records')
data1
collection.insert_many(data1)
# Out:
# InsertManyResult([ObjectId('6668c67669b832a64f3a7fee'), ObjectId('6668c67669b832a64f3a7fef'), ObjectId('6668c67669b832a64f3a7ff0'), ObjectId('6668c67669b832a64f3a7ff1'), ObjectId('6668c67669b832a64f3a7ff2'), ObjectId('6668c67669b832a64f3a7ff3'), ObjectId('6668c67669b832a64f3a7ff4'), ObjectId('6668c67669b832a64f3a7ff5'), ObjectId('6668c67669b832a64f3a7ff6'), ObjectId('6668c67669b832a64f3a7ff7'), ObjectId('6668c67669b832a64f3a7ff8'), ObjectId('6668c67669b832a64f3a7ff9'), ObjectId('6668c67669b832a64f3a7ffa'), ObjectId('6668c67669b832a64f3a7ffb'), ObjectId('6668c67669b832a64f3a7ffc'), ObjectId('6668c67669b832a64f3a7ffd'), ObjectId('6668c67669b832a64f3a7ffe'), ObjectId('6668c67669b832a64f3a7fff'), ObjectId('6668c67669b832a64f3a8000'), ObjectId('6668c67669b832a64f3a8001'), ObjectId('6668c67669b832a64f3a8002'), ObjectId('6668c67669b832a64f3a8003'), ObjectId('6668c67669b832a64f3a8004'), ObjectId('6668c67669b832a64f3a8005'), ObjectId('6668c67669b832a64f3a8006'), ObjectId('6668c67669b832a64f3a
# ...

# %%
data2 = df2.to_dict(orient='records')
data2
collection.insert_many(data2)

# %%
data3 = df3.to_dict(orient='records')
data3
collection.insert_many(data3)

# %%
from pymongo import MongoClient

# MongoDB Atlas connection
client = MongoClient('mongodb+srv://packstation:pack@cluster0.f6o7lcv.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0')
db = client['PackstationDatabase']
employees_collection = db['employees']

# Employee data
employee_data = [
    {
        "name": "John Doe",
        "email": "john.doe@example.com",
        "phone": "(555) 123-4567",
        "department": "sales"
    },
    {
        "name": "Jane Smith",
        "email": "jane.smith@example.com",
        "phone": "(555) 234-5678",
        "department": "Marketing"
    },
    {
        "name": "Alice Johnson",
        "email": "alice.johnson@example.com",
        "phone": "(555) 345-6789",
        "department": "Sales"
    },
    {
        "name": "Bob Brown",
        "email": "bob.brown@example.com",
        "phone": "(555) 456-7890",
        "department": "delivery"
    },
    {
        "name": "Carol White",
        "email": "carol.white@example.com",
        "phone": "(555) 567-8901",
        "department": "Manager"
    }
]

# Insert data into the employees collection
employees_collection.insert_many(employee_data)

print("Employee data inserted successfully.")
# Out:
# Employee data inserted successfully.
